# %% [markdown]
# <a href="https://colab.research.google.com/github/Dorong36/Apsolution_deepLearning/blob/master/real_last.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/real_last
# Out:
# /content/drive/MyDrive/real_last

# %%
# !unzip -qq "/content/drive/MyDrive/real_last/real_last.zip"

# %%
# %cat /content/drive/MyDrive/real_last/data.yaml
# Out:
# train: C:/Users/smhrd/Desktop/yoloy/yolov5/data/test_each100/train/images
# val: C:/Users/smhrd/Desktop/yoloy/yolov5/data/test_each100/valid/images
#
# nc: 12
# names: ['Apple','Leaf','Branch','Stem','Anthrax','Blotch','Fire_Blight_late','Fire_Blight_early','8','Alternaria_leaf_spot,','Valsa_Canker','11']

# %%
from glob import glob

# %%
train_img_list = glob('/content/drive/MyDrive/real_last/train/images/*')

print(len(train_img_list))
# Out:
# 9387

# %%
test_img_list = glob('/content/drive/MyDrive/real_last/test/images/*')

print(len(test_img_list))
# Out:
# 1263

# %%
valid_img_list = glob('/content/drive/MyDrive/real_last/valid/images/*')

print(len(valid_img_list))
# Out:
# 2511

# %%
with open('/content/drive/MyDrive/real_last/train.txt', 'w') as f:
  f.write('\n'.join(train_img_list) +'\n')

with open('/content/drive/MyDrive/real_last/val.txt', 'w') as f:
  f.write('\n'.join(valid_img_list) + '\n')

# %%
import yaml

# %%
with open('/content/drive/MyDrive/real_last/data.yaml', 'r') as f:
  data = yaml.load(f)

print(data)

data['train'] = '/content/drive/MyDrive/real_last/train.txt'
data['val'] = '/content/drive/MyDrive/real_last/val.txt'

with open('/content/drive/MyDrive/real_last/data.yaml', 'w') as f:
  yaml.dump(data, f)

print(data)
# Out:
# {'train': 'C:/Users/smhrd/Desktop/yoloy/yolov5/data/test_each100/train/images', 'val': 'C:/Users/smhrd/Desktop/yoloy/yolov5/data/test_each100/valid/images', 'nc': 12, 'names': ['Apple', 'Leaf', 'Branch', 'Stem', 'Anthrax', 'Blotch', 'Fire_Blight_late', 'Fire_Blight_early', '8', 'Alternaria_leaf_spot,', 'Valsa_Canker', '11']}
# {'train': '/content/drive/MyDrive/real_last/train.txt', 'val': '/content/drive/MyDrive/real_last/val.txt', 'nc': 12, 'names': ['Apple', 'Leaf', 'Branch', 'Stem', 'Anthrax', 'Blotch', 'Fire_Blight_late', 'Fire_Blight_early', '8', 'Alternaria_leaf_spot,', 'Valsa_Canker', '11']}

# %%
# %cd /content/drive/MyDrive/yolov5
# Out:
# /content/drive/MyDrive/yolov5

# %%
# !python train.py --img 416 --batch 100 --epochs 300 --data /content/drive/MyDrive/real_last/data.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name real_last_result
# Out:
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=/content/drive/MyDrive/real_last/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=100, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=real_last_result, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 15 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-243-g7cef03d Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...
